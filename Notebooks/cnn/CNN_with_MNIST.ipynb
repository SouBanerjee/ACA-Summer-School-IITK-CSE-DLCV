# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this notebook, we will build a Convolutional Neural Network (CNN) for identifying text in an image.
#
# <br/>
#    <img src='../images/2_layer_conv.png' height=80% width=70% />
# <br/>
#
#
# A typical convolutional neural network (CNN) consists of:
# - [Convolution Layers](https://pytorch.org/docs/stable/nn.html#convolution-layers)<br/>
#   &nbsp;&nbsp;&nbsp;&nbsp;  It can be thought of as stack of filters. It is the core component of any CNN.
# - [Pooling Layers](https://pytorch.org/docs/stable/nn.html#pooling-layers)
#   &nbsp;&nbsp;&nbsp;&nbsp;  It is quite common to insert a pooling layer just after a convolution layer in a CNN. It is usually used to bring down the spatial size of the representation learned through a convolution layer.
# - [Fully Connected Layers](https://pytorch.org/docs/stable/nn.html#linear-layers)<br/>
#   &nbsp;&nbsp;&nbsp;&nbsp;  It usually applies a linear tranformation to the input data. We usually use one or more fully-connected-linear layers as the final few layers in a CNN to produce a fixed size output.
#
# While the core components of any CNN is $(i)$ Convolution Layers, $(ii)$ Pooling Layers, and $(iii)$ Fully Connected Layers, any convolutional-neural-network (CNN) can comprise of various other layers, like:<br/>
# - [Padding Layers](https://pytorch.org/docs/stable/nn.html#padding-layers)
# - [Normalization Layers](https://pytorch.org/docs/stable/nn.html#normalization-layers)
# - [Dropout Layers](https://pytorch.org/docs/stable/nn.html#dropout-layers)
# - [Pixel-Shuffle and Upsample Layers](https://pytorch.org/docs/stable/nn.html#vision-layers)
# - [Channel-Shuffle Layers](https://pytorch.org/docs/stable/nn.html#shuffle-layers)
#
# **[CNN Demo](https://cs231n.github.io/convolutional-networks/)**
#
#
# Here we'll use the MNIST dataset which consists of greyscale handwritten digits.
# Each image is 28x28 pixels, you can see a sample imgae in the below
#
# <br/>
# <img src='../images/mnist.png' width="500" />
# <br/>
#
# First we will download MNIST dataset, which is provided through [``torchvision``](https://pytorch.org/vision/stable/index.html) package.

# %% [markdown]
# ### Loading MNIST dataset into train-val-test set

# %%
import torchvision.transforms as transforms 
import torchvision.datasets as datasets

# %% [markdown]
# We usually use various random transformation for training-dataset to get various augmentations.
#
# However, for test-dataset we do not use any random transformations.
#
# Random transformations are provided through [``torchvision.transforms``](https://pytorch.org/vision/stable/transforms.html) package.

# %% [markdown]
# **train-test-transform**

# %%
# Define a transform to normalize the data
train_transform = transforms.Compose([transforms.RandomResizedCrop((28, 28)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

test_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# %%
train_dataset = datasets.MNIST(root='../data', train=True, download=True, transform=train_transform)

# val-dataset refers to the same dataset as train-dataset, however, while validating the model's performance
# we do not use any random-transformation
val_dataset = datasets.MNIST(root='../data', train=True, download=True, transform=test_transform)

test_dataset = datasets.MNIST(root='../data', train=False, download=True, transform=test_transform)

# %% [markdown]
# **Separating train-set into train & validation set**
# - Let's set validation set size as 20%, therefore, we will be using 80% of training set for training
#     the neural network
# - Validating a model while training w.r.t a validation-set can help us from overfitting
# - Validation-set works as an alternative to the actual test-set, as it is assumed that while training
#     we do not have any access to the test-set

# %%
train_set_size = len(train_dataset)
print('train-set-size: {}'.format(train_set_size))
# Out:
# train-set-size: 60000

# %%
all_indices = list(range(train_set_size))
print('len(all_indices): '.format(len(all_indices)))

np.random.shuffle(all_indices)

val_size = int(0.2 * len(all_indices))
train_size = len(all_indices) - val_size
print('val-size: {} train-size: {}'.format(val_size, train_size))

val_indices = all_indices[:val_size]
train_indices = all_indices[val_size:]

print('len(train_indices): {} len(val_indices): {}'.format(len(train_indices), len(val_indices)))
# Out:
# len(all_indices):
# val-size: 12000 train-size: 48000
# len(train_indices): 48000 len(val_indices): 12000

# %%
from torch.utils.data import SubsetRandomSampler

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, 
                                           sampler=SubsetRandomSampler(train_indices), num_workers=4, 
                                           pin_memory=True)

val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64,
                                        sampler=SubsetRandomSampler(val_indices), num_workers=4,
                                        pin_memory=True)


test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True,
                                          num_workers=4, pin_memory=True)

# %%
train_batch, _ = next(iter(train_loader))
val_batch, _ = next(iter(val_loader))
test_batch, _ = next(iter(test_loader))

# %%
import torchvision

train_grid_img = torchvision.utils.make_grid(train_batch, nrow=8)
val_grid_img = torchvision.utils.make_grid(val_batch, nrow=8)
test_grid_img = torchvision.utils.make_grid(test_batch, nrow=8)

# %% [markdown]
# #### Display a batch of training data

# %%
plt.imshow(train_grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### Display a batch of validation data

# %%
plt.imshow(val_grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### Display a batch of test data

# %%
plt.imshow(test_grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# !python --version
# Out:
# Python 3.7.7

# %% [markdown]
# ### Calculating Output Dimension Of A Convolution Layer

# %% [markdown]
# Consider:
# - spatial dimention (height/width) of the input image: $f$
# - kernel size of the convolution layer: $k$
# - padding size: $p$
# - stride size: $s$
#
# <br/>
#
# Then, the output dimension of the input image after convolution operation is -
#
# <br/>
#
# \begin{equation}
#     o = \lfloor \frac{f - k + 2p}{s} + 1 \rfloor
# \end{equation}

# %% [markdown]
# ## Define CNN Architecture (Type - 1)

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet1(nn.Module):
    def __init__(self, in_channels: int=1, num_classes: int=10) -> None:
        super(LeNet1, self).__init__()

        self.in_channels = in_channels
        self.num_classes = num_classes

        # default padding = 0, stride = 1
        self.conv1 = nn.Conv2d(in_channels=self.in_channels, out_channels=6, kernel_size=5)
        # default padding = 0, stride = 1
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5)
        self.fc1   = nn.Linear(in_features=16*4*4, out_features=120)
        self.fc2   = nn.Linear(in_features=120, out_features=84)
        self.fc3   = nn.Linear(in_features=84, out_features=self.num_classes)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2) # kernel-size = 2, stride = 2, padding = 0
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2) # kernel-size = 2, stride = 2, padding = 0
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %%
model = LeNet1()
print(model)

data = torch.randn(10, 1, 28, 28)
with torch.no_grad():
    output = model(data)

print('data.shape: {} output.shape: {}'.format(data.size(), output.size()))
# Out:
# LeNet1(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )
# data.shape: torch.Size([10, 1, 28, 28]) output.shape: torch.Size([10, 10])

# %% [markdown]
# ## Define CNN Architecture (Type - 2)

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet2(nn.Module):
    def __init__(self, in_channels: int=1, num_classes: int=10, rate: float=0.4) -> None:
        super(LeNet2, self).__init__()

        self.in_channels = in_channels
        self.num_classes = num_classes
        self.rate = rate
        
        # default padding = 0, stride = 1
        self.conv1 = nn.Conv2d(in_channels=self.in_channels, out_channels=6, kernel_size=5)
        # default padding = 0, stride = 1 
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5)
        self.fc1   = nn.Linear(in_features=16*4*4, out_features=120)
        self.dropout1 = nn.Dropout(p=self.rate)
        self.fc2   = nn.Linear(in_features=120, out_features=84)
        self.dropout2 = nn.Dropout(p=self.rate)
        self.fc3   = nn.Linear(in_features=84, out_features=self.num_classes)
        self.dropout3 = nn.Dropout(p=self.rate)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2) # kernel-size = 2, stride = 2, padding = 0
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2) # kernel-size = 2, stride = 2, padding = 0
        out = out.view(out.size(0), -1)
        out = self.dropout1(out)
        out = F.relu(self.fc1(out))
        out = self.dropout2(out)
        out = F.relu(self.fc2(out))
        out = self.dropout3(out)
        out = self.fc3(out)
        return out

# %%
model = LeNet2()
print(model)

data = torch.randn(10, 1, 28, 28)
with torch.no_grad():
    output = model(data)

print('data.shape: {} output.shape: {}'.format(data.size(), output.size()))
# Out:
# LeNet2(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (dropout1): Dropout(p=0.4, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout2): Dropout(p=0.4, inplace=False)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
#   (dropout3): Dropout(p=0.4, inplace=False)
# )
# data.shape: torch.Size([10, 1, 28, 28]) output.shape: torch.Size([10, 10])

# %% [markdown]
# ## CNN training

# %%
import torch
import torch.nn as nn
from torch.nn import DataParallel
import time
import torch.optim as optim

from typing import Tuple, Any, List

def trainCls(model: nn.Module, train_loader: torch.utils.data.DataLoader, 
             val_loader: torch.utils.data.DataLoader, lr: float=0.1, epochs: int=100, 
             momentum: float=0.9, weight_decay: float=5e-4, 
             checkpoint: str='./checkpoint') -> Tuple[nn.Module, List, List, List, List]:
    
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print('device: {}'.format(device))
    
    model.to(device) # loading model to device

    if torch.cuda.device_count() > 1:
        if not isinstance(model, DataParallel):
            model = DataParallel(model) # if more that one gpu is available,
                                        # then wrap model with DataParallel,
                                        # so that it can be trained on multiple gpus
    
    model.to(device) # load model to device

    criterion = nn.CrossEntropyLoss() # loss-function for classification
    
    # optimizer is used to optime the model parameters while doing back-propagation
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)

    start = time.time()
    best_acc = 0.0
    
    trainLoss_, valLoss_ = list(), list()
    trainAcc_, valAcc_ = list(), list()
    
    start_epoch = 0

    for epoch in range(start_epoch, epochs):
        model.train()
        train_loss, train_acc = 0.0, 0.0
        for _, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            model.zero_grad()
            
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * data.size(0)
            _, predicted = output.max(1)
            train_acc += predicted.eq(target).sum().item()
        
        train_loss, train_acc = train_loss/len(train_loader.sampler), train_acc/len(train_loader.sampler)
        trainLoss_.append(train_loss)
        trainAcc_.append(train_acc)

        val_loss, val_acc = 0.0, 0.0
        model.eval()
        for _, (data, target) in enumerate(val_loader):
            data, target = data.to(device), target.to(device)

            output = model(data)
            loss = criterion(output, target)
            
            val_loss += loss.item() * data.size(0)
            _, predicted = output.max(1)
            val_acc += predicted.eq(target).sum().item()
        
        val_loss, val_acc = val_loss/len(val_loader.sampler), val_acc/len(val_loader.sampler)
        valLoss_.append(val_loss)
        valAcc_.append(val_acc)

        if val_acc > best_acc:
            print('Epoch: {} val accuracy improved: {:0.4f} ==> {:0.4f}'.format(epoch+1, best_acc, val_acc))
            best_acc = val_acc

            try:
                state_dict = model.state_dict()
            except:
                state_dict = model.module.state_dict()

            torch.save(state_dict, checkpoint)

        print('Epoch: [{}/{}] train_acc: {:0.4f} val_acc: {:0.4f} train_loss: {:0.4f} val_loss: {:0.4f}'.format(epoch+1, epochs, train_acc, val_acc, train_loss, val_loss))

    total_time = time.time() - start
    print('time: {:0.0f}m {:0.0f}s'.format((total_time//60), (total_time%60)))
    
    # loading model's best saved weight
    try:
        model.load_state_dict(torch.load(checkpoint, map_location=device))
    except:
        model.module.load_state_dict(torch.load(checkpoint, map_location=device))

    return model, trainLoss_, valLoss_, trainAcc_, valAcc_

# %% [markdown]
# ## CNN evaluation

# %%
def testCls(model: nn.Module, test_loader: torch.utils.data.DataLoader, 
            checkpoint: str) -> Tuple[nn.Module, float, float]:
    
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print('device: {}'.format(device))
    
    model.to(device) # loading model to device

    if torch.cuda.device_count() > 1:
        if not isinstance(model, DataParallel):
            model = DataParallel(model) # if more that one gpu is available,
                                        # then wrap model with DataParallel,
                                        # so that it can be trained on multiple gpus
    
    model.to(device) # load model to device

    criterion = nn.CrossEntropyLoss() # loss-function for classification
    
    # loading model's saved weight
    try:
        model.load_state_dict(torch.load(checkpoint, map_location=device))
    except:
        model.module.load_state_dict(torch.load(checkpoint, map_location=device))

    model.eval()
    
    test_loss, test_acc = 0.0, 0.0
    for _, (data, target) in enumerate(test_loader):
        data, target = data.to(device), target.to(device)

        data = data.to(memory_format=torch.contiguous_format)

        output = model(data)
        loss = criterion(output, target)
        test_loss += loss.item() * data.size(0)
        _, predicted = output.max(1)
        test_acc += predicted.eq(target).sum().item()

    test_loss, test_acc = test_loss/len(test_loader.sampler), test_acc/len(test_loader.sampler)

    print('test_loss: {:0.4f} \t test_acc: {:0.4f}'.format(test_loss, test_acc))

    return model, test_loss, test_acc

# %% [markdown]
# ### Training CNN (Type - 1) with Pytorch

# %%
model = LeNet1()
print(model, '\n\n')
# Out:
# LeNet1(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
# momentum, weight-decay will be discussed in the later classes

model, train_loss, val_loss, train_acc, val_acc = trainCls(model, train_loader, val_loader, 
                                                           lr=0.002, epochs=100, momentum=0.9, 
                                        weight_decay=5e-4, checkpoint='cnn_type_1_best_model.pth')
# Out:
# device: cuda:0
# Epoch: 1 val accuracy improved: 0.0000 ==> 0.3832
# Epoch: [1/100] train_acc: 0.1708 val_acc: 0.3832 train_loss: 2.2810 val_loss: 2.0597
# Epoch: 2 val accuracy improved: 0.3832 ==> 0.7240
# Epoch: [2/100] train_acc: 0.3638 val_acc: 0.7240 train_loss: 1.8736 val_loss: 0.9946
# Epoch: 3 val accuracy improved: 0.7240 ==> 0.8095
# Epoch: [3/100] train_acc: 0.5130 val_acc: 0.8095 train_loss: 1.4258 val_loss: 0.6138
# Epoch: [4/100] train_acc: 0.5815 val_acc: 0.8046 train_loss: 1.2144 val_loss: 0.5584
# Epoch: 5 val accuracy improved: 0.8095 ==> 0.8595
# Epoch: [5/100] train_acc: 0.6195 val_acc: 0.8595 train_loss: 1.1106 val_loss: 0.4300
# Epoch: 6 val accuracy improved: 0.8595 ==> 0.8702
# Epoch: [6/100] train_acc: 0.6443 val_acc: 0.8702 train_loss: 1.0417 val_loss: 0.3733
# Epoch: 7 val accuracy improved: 0.8702 ==> 0.8932
# Epoch: [7/100] train_acc: 0.6640 val_acc: 0.8932 train_loss: 0.9817 val_loss: 0.3301
# Epoch: 8 val accuracy improved: 0.8932 ==> 0.9155
# Epoch: [8/100] train_acc: 0.6778 val_acc: 0.9155 train_loss: 0.9432 val_loss: 0.2806
# Epoch: [9/100] train_acc: 0.6961 val_acc: 0.9073 train_loss: 0.8951 val_loss: 0.2885
# Epoch: [10/100] train_acc: 0.7011 val_acc: 0.9105 train_loss: 0.8802 val_loss: 0.2722
# Epoch: 11 val accuracy improved: 0.9155 ==> 0.9321
# Epoch: [11/100] train_acc: 0.7117 val_acc: 0.9321 train_loss: 0.8477 val_loss: 0.2219
# Epoch: [12/100] train_acc: 0.7225 val_acc: 0.9306 train_loss: 0.8240 val_loss: 0.2207
# Epoch: [13/100] train_acc: 0.7306 val_acc: 0.9293 train_loss: 0.7940 val_loss: 0.2258
# Epoch: 14 val accuracy improved: 0.9321 ==> 0.9377
# Epoch: [14/100] train_acc: 0.7368 val_acc: 0.9377 train_loss: 0.7830 val_loss: 0.1978
# Epoch: [15/100] train_acc: 0.7392 val_acc: 0.9366 train_loss: 0.7682 val_loss: 0.1989
# Epoch: [16/100] train_acc: 0.7417 val_acc: 0.9326 train_loss: 0.7625 val_loss: 0.2114
# Epoch: 17 val accuracy improved: 0.9377 ==> 0.9444
# Epoch: [17/100] train_acc: 0.7484 val_acc: 0.9444 train_loss: 0.7496 val_loss: 0.1751
# Epoch: 18 val accuracy improved: 0.9444 ==> 0.9492
# Epoch: [18/100] train_acc: 0.7469 val_acc: 0.9492 train_loss: 0.7438 val_loss: 0.1680
# Epoch: [19/100] train_acc: 0.7549 val_acc: 0.9491 train_loss: 0.7257 val_loss: 0.1608
# Epoch: [20/100] train_acc: 0.7590 val_acc: 0.9396 train_loss: 0.7147 val_loss: 0.1871
# Epoch: 21 val accuracy improved: 0.9492 ==> 0.9530
# Epoch: [21/100] train_acc: 0.7588 val_acc: 0.9530 train_loss: 0.7053 val_loss: 0.1583
# Epoch: [22/100] train_acc: 0.7646 val_acc: 0.9465 train_loss: 0.6944 val_loss: 0.1693
# Epoch: [23/100] train_acc: 0.7614 val_acc: 0.9427 train_loss: 0.6998 val_loss: 0.1829
# Epoch: 24 val accuracy improved: 0.9530 ==> 0.9569
# Epoch: [24/100] train_acc: 0.7683 val_acc: 0.9569 train_loss: 0.6892 val_loss: 0.1426
# Epoch: [25/100] train_acc: 0.7707 val_acc: 0.9561 train_loss: 0.6782 val_loss: 0.1397
# Epoch: [26/100] train_acc: 0.7739 val_acc: 0.9434 train_loss: 0.6656 val_loss: 0.1771
# Epoch: [27/100] train_acc: 0.7768 val_acc: 0.9567 train_loss: 0.6617 val_loss: 0.1428
# Epoch: [28/100] train_acc: 0.7783 val_acc: 0.9502 train_loss: 0.6553 val_loss: 0.1499
# Epoch: 29 val accuracy improved: 0.9569 ==> 0.9575
# Epoch: [29/100] train_acc: 0.7790 val_acc: 0.9575 train_loss: 0.6566 val_loss: 0.1355
# Epoch: [30/100] train_acc: 0.7790 val_acc: 0.9547 train_loss: 0.6527 val_loss: 0.1396
# Epoch: [31/100] train_acc: 0.7812 val_acc: 0.9567 train_loss: 0.6436 val_loss: 0.1428
# Epoch: 32 val accuracy improved: 0.9575 ==> 0.9635
# Epoch: [32/100] train_acc: 0.7836 val_acc: 0.9635 train_loss: 0.6376 val_loss: 0.1182
# Epoch: [33/100] train_acc: 0.7841 val_acc: 0.9600 train_loss: 0.6387 val_loss: 0.1318
# Epoch: [34/100] train_acc: 0.7849 val_acc: 0.9601 train_loss: 0.6358 val_loss: 0.1309
# Epoch: [35/100] train_acc: 0.7843 val_acc: 0.9628 train_loss: 0.6291 val_loss: 0.1185
# Epoch: [36/100] train_acc: 0.7897 val_acc: 0.9537 train_loss: 0.6222 val_loss: 0.1442
# Epoch: [37/100] train_acc: 0.7866 val_acc: 0.9572 train_loss: 0.6280 val_loss: 0.1392
# Epoch: [38/100] train_acc: 0.7913 val_acc: 0.9607 train_loss: 0.6167 val_loss: 0.1256
# Epoch: [39/100] train_acc: 0.7931 val_acc: 0.9563 train_loss: 0.6097 val_loss: 0.1364
# Epoch: [40/100] train_acc: 0.7946 val_acc: 0.9627 train_loss: 0.6045 val_loss: 0.1184
# Epoch: [41/100] train_acc: 0.7935 val_acc: 0.9510 train_loss: 0.6076 val_loss: 0.1483
# Epoch: [42/100] train_acc: 0.7962 val_acc: 0.9626 train_loss: 0.6022 val_loss: 0.1174
# Epoch: 43 val accuracy improved: 0.9635 ==> 0.9669
# Epoch: [43/100] train_acc: 0.7943 val_acc: 0.9669 train_loss: 0.6054 val_loss: 0.1088
# Epoch: [44/100] train_acc: 0.7970 val_acc: 0.9580 train_loss: 0.5980 val_loss: 0.1307
# Epoch: [45/100] train_acc: 0.7966 val_acc: 0.9583 train_loss: 0.5996 val_loss: 0.1237
# Epoch: 46 val accuracy improved: 0.9669 ==> 0.9684
# Epoch: [46/100] train_acc: 0.7989 val_acc: 0.9684 train_loss: 0.5925 val_loss: 0.1043
# Epoch: [47/100] train_acc: 0.7994 val_acc: 0.9640 train_loss: 0.5919 val_loss: 0.1116
# Epoch: [48/100] train_acc: 0.8011 val_acc: 0.9524 train_loss: 0.5863 val_loss: 0.1462
# Epoch: 49 val accuracy improved: 0.9684 ==> 0.9685
# Epoch: [49/100] train_acc: 0.8031 val_acc: 0.9685 train_loss: 0.5826 val_loss: 0.1026
# Epoch: [50/100] train_acc: 0.7994 val_acc: 0.9647 train_loss: 0.5887 val_loss: 0.1099
# Epoch: [51/100] train_acc: 0.7998 val_acc: 0.9607 train_loss: 0.5883 val_loss: 0.1209
# Epoch: [52/100] train_acc: 0.8032 val_acc: 0.9633 train_loss: 0.5794 val_loss: 0.1230
# Epoch: [53/100] train_acc: 0.8032 val_acc: 0.9670 train_loss: 0.5814 val_loss: 0.1061
# Epoch: 54 val accuracy improved: 0.9685 ==> 0.9715
# Epoch: [54/100] train_acc: 0.8039 val_acc: 0.9715 train_loss: 0.5721 val_loss: 0.0954
# Epoch: [55/100] train_acc: 0.8044 val_acc: 0.9619 train_loss: 0.5716 val_loss: 0.1190
# Epoch: [56/100] train_acc: 0.8027 val_acc: 0.9660 train_loss: 0.5830 val_loss: 0.1055
# Epoch: [57/100] train_acc: 0.8058 val_acc: 0.9658 train_loss: 0.5700 val_loss: 0.1186
# Epoch: [58/100] train_acc: 0.8050 val_acc: 0.9613 train_loss: 0.5725 val_loss: 0.1212
# Epoch: [59/100] train_acc: 0.8066 val_acc: 0.9702 train_loss: 0.5679 val_loss: 0.0939
# Epoch: [60/100] train_acc: 0.8049 val_acc: 0.9706 train_loss: 0.5771 val_loss: 0.0972
# Epoch: [61/100] train_acc: 0.8056 val_acc: 0.9633 train_loss: 0.5718 val_loss: 0.1128
# Epoch: [62/100] train_acc: 0.8085 val_acc: 0.9700 train_loss: 0.5645 val_loss: 0.0946
# Epoch: [63/100] train_acc: 0.8060 val_acc: 0.9696 train_loss: 0.5656 val_loss: 0.0925
# Epoch: [64/100] train_acc: 0.8078 val_acc: 0.9708 train_loss: 0.5628 val_loss: 0.0911
# Epoch: [65/100] train_acc: 0.8068 val_acc: 0.9704 train_loss: 0.5639 val_loss: 0.0931
# Epoch: [66/100] train_acc: 0.8073 val_acc: 0.9633 train_loss: 0.5662 val_loss: 0.1145
# Epoch: [67/100] train_acc: 0.8098 val_acc: 0.9701 train_loss: 0.5614 val_loss: 0.0944
# Epoch: [68/100] train_acc: 0.8116 val_acc: 0.9702 train_loss: 0.5574 val_loss: 0.0966
# Epoch: [69/100] train_acc: 0.8097 val_acc: 0.9643 train_loss: 0.5594 val_loss: 0.1146
# Epoch: [70/100] train_acc: 0.8112 val_acc: 0.9688 train_loss: 0.5543 val_loss: 0.1003
# Epoch: [71/100] train_acc: 0.8120 val_acc: 0.9633 train_loss: 0.5608 val_loss: 0.1130
# Epoch: [72/100] train_acc: 0.8116 val_acc: 0.9707 train_loss: 0.5505 val_loss: 0.0895
# Epoch: [73/100] train_acc: 0.8129 val_acc: 0.9669 train_loss: 0.5487 val_loss: 0.0983
# Epoch: [74/100] train_acc: 0.8136 val_acc: 0.9706 train_loss: 0.5508 val_loss: 0.0901
# Epoch: [75/100] train_acc: 0.8139 val_acc: 0.9627 train_loss: 0.5499 val_loss: 0.1138
# Epoch: [76/100] train_acc: 0.8121 val_acc: 0.9630 train_loss: 0.5476 val_loss: 0.1156
# Epoch: 77 val accuracy improved: 0.9715 ==> 0.9725
# Epoch: [77/100] train_acc: 0.8164 val_acc: 0.9725 train_loss: 0.5406 val_loss: 0.0902
# Epoch: [78/100] train_acc: 0.8138 val_acc: 0.9673 train_loss: 0.5438 val_loss: 0.1045
# Epoch: [79/100] train_acc: 0.8171 val_acc: 0.9644 train_loss: 0.5434 val_loss: 0.1105
# Epoch: [80/100] train_acc: 0.8176 val_acc: 0.9674 train_loss: 0.5378 val_loss: 0.0996
# Epoch: [81/100] train_acc: 0.8138 val_acc: 0.9696 train_loss: 0.5483 val_loss: 0.0923
# Epoch: 82 val accuracy improved: 0.9725 ==> 0.9732
# Epoch: [82/100] train_acc: 0.8148 val_acc: 0.9732 train_loss: 0.5421 val_loss: 0.0849
# Epoch: [83/100] train_acc: 0.8185 val_acc: 0.9730 train_loss: 0.5344 val_loss: 0.0864
# Epoch: [84/100] train_acc: 0.8158 val_acc: 0.9686 train_loss: 0.5425 val_loss: 0.0977
# Epoch: 85 val accuracy improved: 0.9732 ==> 0.9735
# Epoch: [85/100] train_acc: 0.8164 val_acc: 0.9735 train_loss: 0.5384 val_loss: 0.0872
# Epoch: [86/100] train_acc: 0.8173 val_acc: 0.9620 train_loss: 0.5365 val_loss: 0.1212
# Epoch: [87/100] train_acc: 0.8176 val_acc: 0.9697 train_loss: 0.5359 val_loss: 0.0920
# Epoch: [88/100] train_acc: 0.8174 val_acc: 0.9649 train_loss: 0.5355 val_loss: 0.1042
# Epoch: [89/100] train_acc: 0.8183 val_acc: 0.9707 train_loss: 0.5314 val_loss: 0.0966
# Epoch: [90/100] train_acc: 0.8193 val_acc: 0.9694 train_loss: 0.5367 val_loss: 0.0965
# Epoch: [91/100] train_acc: 0.8155 val_acc: 0.9711 train_loss: 0.5416 val_loss: 0.0918
# Epoch: [92/100] train_acc: 0.8163 val_acc: 0.9688 train_loss: 0.5355 val_loss: 0.0947
# Epoch: [93/100] train_acc: 0.8196 val_acc: 0.9655 train_loss: 0.5287 val_loss: 0.1106
# Epoch: [94/100] train_acc: 0.8196 val_acc: 0.9728 train_loss: 0.5303 val_loss: 0.0847
# Epoch: 95 val accuracy improved: 0.9735 ==> 0.9753
# Epoch: [95/100] train_acc: 0.8190 val_acc: 0.9753 train_loss: 0.5325 val_loss: 0.0760
# Epoch: [96/100] train_acc: 0.8202 val_acc: 0.9670 train_loss: 0.5306 val_loss: 0.1000
# Epoch: [97/100] train_acc: 0.8209 val_acc: 0.9691 train_loss: 0.5254 val_loss: 0.0963
# Epoch: [98/100] train_acc: 0.8189 val_acc: 0.9725 train_loss: 0.5316 val_loss: 0.0931
# Epoch: [99/100] train_acc: 0.8181 val_acc: 0.9749 train_loss: 0.5309 val_loss: 0.0820
# Epoch: [100/100] train_acc: 0.8203 val_acc: 0.9708 train_loss: 0.5295 val_loss: 0.0907
# time: 12m 20s

# %%
model, test_loss, test_acc = testCls(model, test_loader, checkpoint='cnn_type_1_best_model.pth')
# Out:
# device: cuda:0
# test_loss: 0.0739 	 test_acc: 0.9766

# %%
epochs = list(range(1, 101, 1))

# Plot and label the training and validation loss values
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')

# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(np.arange(1, 105, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
epochs = list(range(1, 101, 1))

# Plot and label the training and validation loss values
plt.plot(epochs, train_acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')

# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Set the tick locations
plt.xticks(np.arange(1, 105, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Training CNN (Type - 2) with Pytorch

# %%
model = LeNet2()
print(model, '\n\n')
# Out:
# LeNet2(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (dropout1): Dropout(p=0.4, inplace=False)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (dropout2): Dropout(p=0.4, inplace=False)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
#   (dropout3): Dropout(p=0.4, inplace=False)
# )

# %%
# momentum, weight-decay will be discussed in the later classes

model, train_loss, val_loss, train_acc, val_acc = trainCls(model, train_loader, val_loader, 
                                                           lr=0.002, epochs=100, momentum=0.9, 
                                        weight_decay=5e-4, checkpoint='cnn_type_2_best_model.pth')
# Out:
# device: cuda:0
# Epoch: 1 val accuracy improved: 0.0000 ==> 0.1128
# Epoch: [1/100] train_acc: 0.1202 val_acc: 0.1128 train_loss: 2.2967 val_loss: 2.2708
# Epoch: 2 val accuracy improved: 0.1128 ==> 0.4675
# Epoch: [2/100] train_acc: 0.1789 val_acc: 0.4675 train_loss: 2.2369 val_loss: 1.7997
# Epoch: 3 val accuracy improved: 0.4675 ==> 0.6713
# Epoch: [3/100] train_acc: 0.2927 val_acc: 0.6713 train_loss: 2.0162 val_loss: 1.3606
# Epoch: 4 val accuracy improved: 0.6713 ==> 0.7187
# Epoch: [4/100] train_acc: 0.3461 val_acc: 0.7187 train_loss: 1.8777 val_loss: 1.1625
# Epoch: 5 val accuracy improved: 0.7187 ==> 0.7260
# Epoch: [5/100] train_acc: 0.3814 val_acc: 0.7260 train_loss: 1.7898 val_loss: 1.0279
# Epoch: 6 val accuracy improved: 0.7260 ==> 0.7293
# Epoch: [6/100] train_acc: 0.4077 val_acc: 0.7293 train_loss: 1.7132 val_loss: 0.9250
# Epoch: 7 val accuracy improved: 0.7293 ==> 0.7858
# Epoch: [7/100] train_acc: 0.4345 val_acc: 0.7858 train_loss: 1.6328 val_loss: 0.7874
# Epoch: 8 val accuracy improved: 0.7858 ==> 0.8027
# Epoch: [8/100] train_acc: 0.4573 val_acc: 0.8027 train_loss: 1.5752 val_loss: 0.6793
# Epoch: [9/100] train_acc: 0.4759 val_acc: 0.7916 train_loss: 1.5186 val_loss: 0.6716
# Epoch: 10 val accuracy improved: 0.8027 ==> 0.8046
# Epoch: [10/100] train_acc: 0.4859 val_acc: 0.8046 train_loss: 1.4916 val_loss: 0.6542
# Epoch: 11 val accuracy improved: 0.8046 ==> 0.8152
# Epoch: [11/100] train_acc: 0.5082 val_acc: 0.8152 train_loss: 1.4379 val_loss: 0.5733
# Epoch: 12 val accuracy improved: 0.8152 ==> 0.8275
# Epoch: [12/100] train_acc: 0.5190 val_acc: 0.8275 train_loss: 1.4070 val_loss: 0.5550
# Epoch: 13 val accuracy improved: 0.8275 ==> 0.8359
# Epoch: [13/100] train_acc: 0.5276 val_acc: 0.8359 train_loss: 1.3779 val_loss: 0.5127
# Epoch: [14/100] train_acc: 0.5404 val_acc: 0.8226 train_loss: 1.3520 val_loss: 0.5426
# Epoch: 15 val accuracy improved: 0.8359 ==> 0.8438
# Epoch: [15/100] train_acc: 0.5457 val_acc: 0.8438 train_loss: 1.3258 val_loss: 0.4699
# Epoch: 16 val accuracy improved: 0.8438 ==> 0.8520
# Epoch: [16/100] train_acc: 0.5555 val_acc: 0.8520 train_loss: 1.3039 val_loss: 0.4478
# Epoch: 17 val accuracy improved: 0.8520 ==> 0.8616
# Epoch: [17/100] train_acc: 0.5610 val_acc: 0.8616 train_loss: 1.2842 val_loss: 0.4530
# Epoch: 18 val accuracy improved: 0.8616 ==> 0.8888
# Epoch: [18/100] train_acc: 0.5719 val_acc: 0.8888 train_loss: 1.2637 val_loss: 0.4165
# Epoch: [19/100] train_acc: 0.5754 val_acc: 0.8558 train_loss: 1.2494 val_loss: 0.4315
# Epoch: [20/100] train_acc: 0.5810 val_acc: 0.8605 train_loss: 1.2378 val_loss: 0.4152
# Epoch: [21/100] train_acc: 0.5814 val_acc: 0.8851 train_loss: 1.2328 val_loss: 0.3765
# Epoch: [22/100] train_acc: 0.5906 val_acc: 0.8746 train_loss: 1.2105 val_loss: 0.3848
# Epoch: [23/100] train_acc: 0.5914 val_acc: 0.8855 train_loss: 1.2057 val_loss: 0.4024
# Epoch: 24 val accuracy improved: 0.8888 ==> 0.8902
# Epoch: [24/100] train_acc: 0.5970 val_acc: 0.8902 train_loss: 1.1877 val_loss: 0.3558
# Epoch: 25 val accuracy improved: 0.8902 ==> 0.9029
# Epoch: [25/100] train_acc: 0.6025 val_acc: 0.9029 train_loss: 1.1777 val_loss: 0.3531
# Epoch: 26 val accuracy improved: 0.9029 ==> 0.9039
# Epoch: [26/100] train_acc: 0.6024 val_acc: 0.9039 train_loss: 1.1734 val_loss: 0.3402
# Epoch: [27/100] train_acc: 0.6068 val_acc: 0.8904 train_loss: 1.1688 val_loss: 0.3619
# Epoch: [28/100] train_acc: 0.6136 val_acc: 0.8944 train_loss: 1.1432 val_loss: 0.3376
# Epoch: 29 val accuracy improved: 0.9039 ==> 0.9065
# Epoch: [29/100] train_acc: 0.6156 val_acc: 0.9065 train_loss: 1.1442 val_loss: 0.3307
# Epoch: 30 val accuracy improved: 0.9065 ==> 0.9143
# Epoch: [30/100] train_acc: 0.6150 val_acc: 0.9143 train_loss: 1.1442 val_loss: 0.3134
# Epoch: 31 val accuracy improved: 0.9143 ==> 0.9151
# Epoch: [31/100] train_acc: 0.6175 val_acc: 0.9151 train_loss: 1.1361 val_loss: 0.2962
# Epoch: 32 val accuracy improved: 0.9151 ==> 0.9169
# Epoch: [32/100] train_acc: 0.6244 val_acc: 0.9169 train_loss: 1.1156 val_loss: 0.3101
# Epoch: 33 val accuracy improved: 0.9169 ==> 0.9293
# Epoch: [33/100] train_acc: 0.6300 val_acc: 0.9293 train_loss: 1.1056 val_loss: 0.2681
# Epoch: [34/100] train_acc: 0.6343 val_acc: 0.9246 train_loss: 1.0977 val_loss: 0.2788
# Epoch: [35/100] train_acc: 0.6275 val_acc: 0.9028 train_loss: 1.1047 val_loss: 0.3140
# Epoch: [36/100] train_acc: 0.6340 val_acc: 0.9243 train_loss: 1.0918 val_loss: 0.2779
# Epoch: [37/100] train_acc: 0.6394 val_acc: 0.9275 train_loss: 1.0816 val_loss: 0.2686
# Epoch: 38 val accuracy improved: 0.9293 ==> 0.9300
# Epoch: [38/100] train_acc: 0.6387 val_acc: 0.9300 train_loss: 1.0801 val_loss: 0.2607
# Epoch: [39/100] train_acc: 0.6414 val_acc: 0.9256 train_loss: 1.0766 val_loss: 0.2678
# Epoch: [40/100] train_acc: 0.6472 val_acc: 0.9233 train_loss: 1.0645 val_loss: 0.2596
# Epoch: 41 val accuracy improved: 0.9300 ==> 0.9319
# Epoch: [41/100] train_acc: 0.6443 val_acc: 0.9319 train_loss: 1.0608 val_loss: 0.2462
# Epoch: [42/100] train_acc: 0.6479 val_acc: 0.9261 train_loss: 1.0546 val_loss: 0.2614
# Epoch: 43 val accuracy improved: 0.9319 ==> 0.9343
# Epoch: [43/100] train_acc: 0.6521 val_acc: 0.9343 train_loss: 1.0494 val_loss: 0.2313
# Epoch: 44 val accuracy improved: 0.9343 ==> 0.9357
# Epoch: [44/100] train_acc: 0.6539 val_acc: 0.9357 train_loss: 1.0473 val_loss: 0.2298
# Epoch: [45/100] train_acc: 0.6535 val_acc: 0.9340 train_loss: 1.0462 val_loss: 0.2346
# Epoch: 46 val accuracy improved: 0.9357 ==> 0.9358
# Epoch: [46/100] train_acc: 0.6527 val_acc: 0.9358 train_loss: 1.0544 val_loss: 0.2307
# Epoch: 47 val accuracy improved: 0.9358 ==> 0.9382
# Epoch: [47/100] train_acc: 0.6535 val_acc: 0.9382 train_loss: 1.0411 val_loss: 0.2180
# Epoch: [48/100] train_acc: 0.6543 val_acc: 0.9352 train_loss: 1.0365 val_loss: 0.2353
# Epoch: [49/100] train_acc: 0.6558 val_acc: 0.9352 train_loss: 1.0343 val_loss: 0.2235
# Epoch: 50 val accuracy improved: 0.9382 ==> 0.9387
# Epoch: [50/100] train_acc: 0.6584 val_acc: 0.9387 train_loss: 1.0311 val_loss: 0.2155
# Epoch: [51/100] train_acc: 0.6628 val_acc: 0.9382 train_loss: 1.0221 val_loss: 0.2209
# Epoch: [52/100] train_acc: 0.6635 val_acc: 0.9282 train_loss: 1.0184 val_loss: 0.2363
# Epoch: [53/100] train_acc: 0.6605 val_acc: 0.9303 train_loss: 1.0249 val_loss: 0.2360
# Epoch: 54 val accuracy improved: 0.9387 ==> 0.9453
# Epoch: [54/100] train_acc: 0.6620 val_acc: 0.9453 train_loss: 1.0190 val_loss: 0.2105
# Epoch: [55/100] train_acc: 0.6643 val_acc: 0.9452 train_loss: 1.0179 val_loss: 0.2030
# Epoch: [56/100] train_acc: 0.6611 val_acc: 0.9389 train_loss: 1.0193 val_loss: 0.2190
# Epoch: [57/100] train_acc: 0.6644 val_acc: 0.9387 train_loss: 1.0066 val_loss: 0.2073
# Epoch: [58/100] train_acc: 0.6673 val_acc: 0.9433 train_loss: 1.0024 val_loss: 0.2013
# Epoch: [59/100] train_acc: 0.6695 val_acc: 0.9403 train_loss: 1.0001 val_loss: 0.2074
# Epoch: [60/100] train_acc: 0.6683 val_acc: 0.9403 train_loss: 1.0065 val_loss: 0.2047
# Epoch: [61/100] train_acc: 0.6670 val_acc: 0.9453 train_loss: 1.0029 val_loss: 0.1932
# Epoch: 62 val accuracy improved: 0.9453 ==> 0.9479
# Epoch: [62/100] train_acc: 0.6688 val_acc: 0.9479 train_loss: 1.0015 val_loss: 0.1851
# Epoch: [63/100] train_acc: 0.6735 val_acc: 0.9477 train_loss: 0.9934 val_loss: 0.1837
# Epoch: [64/100] train_acc: 0.6753 val_acc: 0.9397 train_loss: 0.9835 val_loss: 0.2023
# Epoch: [65/100] train_acc: 0.6698 val_acc: 0.9472 train_loss: 0.9924 val_loss: 0.1854
# Epoch: [66/100] train_acc: 0.6714 val_acc: 0.9437 train_loss: 0.9952 val_loss: 0.1919
# Epoch: 67 val accuracy improved: 0.9479 ==> 0.9483
# Epoch: [67/100] train_acc: 0.6717 val_acc: 0.9483 train_loss: 0.9920 val_loss: 0.1787
# Epoch: [68/100] train_acc: 0.6759 val_acc: 0.9440 train_loss: 0.9843 val_loss: 0.1983
# Epoch: [69/100] train_acc: 0.6776 val_acc: 0.9452 train_loss: 0.9781 val_loss: 0.1868
# Epoch: 70 val accuracy improved: 0.9483 ==> 0.9503
# Epoch: [70/100] train_acc: 0.6745 val_acc: 0.9503 train_loss: 0.9807 val_loss: 0.1725
# Epoch: 71 val accuracy improved: 0.9503 ==> 0.9522
# Epoch: [71/100] train_acc: 0.6760 val_acc: 0.9522 train_loss: 0.9794 val_loss: 0.1704
# Epoch: [72/100] train_acc: 0.6777 val_acc: 0.9421 train_loss: 0.9696 val_loss: 0.1952
# Epoch: [73/100] train_acc: 0.6791 val_acc: 0.9484 train_loss: 0.9720 val_loss: 0.1772
# Epoch: [74/100] train_acc: 0.6784 val_acc: 0.9477 train_loss: 0.9705 val_loss: 0.1822
# Epoch: [75/100] train_acc: 0.6791 val_acc: 0.9472 train_loss: 0.9777 val_loss: 0.1898
# Epoch: [76/100] train_acc: 0.6770 val_acc: 0.9448 train_loss: 0.9750 val_loss: 0.1910
# Epoch: [77/100] train_acc: 0.6763 val_acc: 0.9517 train_loss: 0.9832 val_loss: 0.1744
# Epoch: [78/100] train_acc: 0.6777 val_acc: 0.9465 train_loss: 0.9695 val_loss: 0.1863
# Epoch: [79/100] train_acc: 0.6826 val_acc: 0.9458 train_loss: 0.9614 val_loss: 0.1808
# Epoch: [80/100] train_acc: 0.6807 val_acc: 0.9437 train_loss: 0.9639 val_loss: 0.1875
# Epoch: 81 val accuracy improved: 0.9522 ==> 0.9531
# Epoch: [81/100] train_acc: 0.6808 val_acc: 0.9531 train_loss: 0.9661 val_loss: 0.1651
# Epoch: [82/100] train_acc: 0.6828 val_acc: 0.9500 train_loss: 0.9628 val_loss: 0.1776
# Epoch: [83/100] train_acc: 0.6853 val_acc: 0.9523 train_loss: 0.9567 val_loss: 0.1687
# Epoch: [84/100] train_acc: 0.6852 val_acc: 0.9463 train_loss: 0.9575 val_loss: 0.1851
# Epoch: 85 val accuracy improved: 0.9531 ==> 0.9537
# Epoch: [85/100] train_acc: 0.6840 val_acc: 0.9537 train_loss: 0.9565 val_loss: 0.1650
# Epoch: [86/100] train_acc: 0.6833 val_acc: 0.9496 train_loss: 0.9535 val_loss: 0.1687
# Epoch: [87/100] train_acc: 0.6828 val_acc: 0.9506 train_loss: 0.9539 val_loss: 0.1698
# Epoch: [88/100] train_acc: 0.6855 val_acc: 0.9535 train_loss: 0.9524 val_loss: 0.1580
# Epoch: [89/100] train_acc: 0.6838 val_acc: 0.9517 train_loss: 0.9570 val_loss: 0.1681
# Epoch: [90/100] train_acc: 0.6851 val_acc: 0.9534 train_loss: 0.9564 val_loss: 0.1605
# Epoch: [91/100] train_acc: 0.6857 val_acc: 0.9498 train_loss: 0.9551 val_loss: 0.1706
# Epoch: 92 val accuracy improved: 0.9537 ==> 0.9548
# Epoch: [92/100] train_acc: 0.6836 val_acc: 0.9548 train_loss: 0.9519 val_loss: 0.1576
# Epoch: [93/100] train_acc: 0.6826 val_acc: 0.9483 train_loss: 0.9557 val_loss: 0.1794
# Epoch: [94/100] train_acc: 0.6877 val_acc: 0.9462 train_loss: 0.9485 val_loss: 0.1871
# Epoch: [95/100] train_acc: 0.6872 val_acc: 0.9503 train_loss: 0.9464 val_loss: 0.1712
# Epoch: [96/100] train_acc: 0.6883 val_acc: 0.9544 train_loss: 0.9487 val_loss: 0.1598
# Epoch: [97/100] train_acc: 0.6857 val_acc: 0.9493 train_loss: 0.9479 val_loss: 0.1749
# Epoch: 98 val accuracy improved: 0.9548 ==> 0.9567
# Epoch: [98/100] train_acc: 0.6900 val_acc: 0.9567 train_loss: 0.9396 val_loss: 0.1473
# Epoch: [99/100] train_acc: 0.6881 val_acc: 0.9518 train_loss: 0.9428 val_loss: 0.1647
# Epoch: [100/100] train_acc: 0.6893 val_acc: 0.9543 train_loss: 0.9434 val_loss: 0.1589
# time: 12m 48s

# %%
model, test_loss, test_acc = testCls(model, test_loader, checkpoint='cnn_type_2_best_model.pth')
# Out:
# device: cuda:0
# test_loss: 0.1342 	 test_acc: 0.9602

# %%
epochs = list(range(1, 101, 1))

# Plot and label the training and validation loss values
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')

# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(np.arange(1, 105, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
epochs = list(range(1, 101, 1))

# Plot and label the training and validation loss values
plt.plot(epochs, train_acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')

# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Set the tick locations
plt.xticks(np.arange(1, 105, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()
