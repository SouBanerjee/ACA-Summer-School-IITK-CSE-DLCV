# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %% [markdown]
# # AutoEncoder Tutorial

# %% [markdown]
# ![](https://lilianweng.github.io/posts/2018-08-12-vae/autoencoder-architecture.png)

# %% [markdown]
# An **AutoEncoder** is a neural networks comprised of two networks: $(i)$ **Encoder** and $(ii)$ **Decoder** network. It is designed to learn an identity function in an unsupervised manner, where Encoder network learns to compress the input image to a latent representation, whereas Decoder network learns to reconstruct the input image from the compressed latent representation by minimizing the reconstruction error.

# %% [markdown]
# Let's consider **Encoder** network $(g_{\phi})$ parameterized by $\phi$ and **Decoder** network $(f_{\theta})$ parameterized by $\theta$. Then, the latent representation learned for any input image $\boldsymbol{x}$ can be denoted as: $\boldsymbol{z} = g_{\phi}(\boldsymbol{x})$, and the reconstructed image $\boldsymbol{x}^{\prime}$ can be denoted as: $\boldsymbol{x}^{\prime} = f_{\theta}(g_{\phi}(\boldsymbol{x}))$.

# %% [markdown]
# The parameters of Encoder and Decoder network $(\phi, \theta)$ are optimized jointly. We use MSE-Loss to measure the reconstruction error between the input image and the reconstructed image.
#
# \begin{equation}
#     L_\text{AE}(\phi,, \theta) = \frac{1}{n}\sum_{i=1}^n (\mathbf{x}^{(i)} - f_\theta(g_\phi(\mathbf{x}^{(i)})))^2
# \end{equation}

# %% [markdown]
# **[Further Reading](https://lilianweng.github.io/posts/2018-08-12-vae/)**

# %% [markdown]
# ### Define Transformation

# %%
train_transform = transforms.Compose([transforms.RandomResizedCrop(32), transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

test_transform = transforms.Compose([transforms.Resize(32), 
                                     transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# %% [markdown]
# ### Load train and test data

# %%
train_dataset = datasets.MNIST(root='../data', train=True, download=True, transform=train_transform)

test_dataset = datasets.MNIST(root='../data', train=False, download=True, transform=test_transform)

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, 
                                           shuffle=True, num_workers=4, 
                                           pin_memory=True)



test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True,
                                          num_workers=4, pin_memory=True)

# %%
train_batch, _ = next(iter(train_loader))

test_batch, _ = next(iter(test_loader))

# %%
train_grid_img = torchvision.utils.make_grid(train_batch, nrow=8)

test_grid_img = torchvision.utils.make_grid(test_batch, nrow=8)

# %% [markdown]
# #### Display a batch of training data

# %%
plt.imshow(train_grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### Display a batch of test data

# %%
plt.imshow(test_grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# !python --version
# Out:
# Python 3.7.7

# %% [markdown]
# ## Define AutoEncoder

# %%
import torch.nn as nn
import torch.nn.init as init

class View(nn.Module):
    def __init__(self, size):
        super(View, self).__init__()
        self.size = size

    def forward(self, tensor):
        return tensor.view(self.size)


class AE(nn.Module):
    
    def __init__(self, z_dim=32, nc=1):
        super(AE, self).__init__()
        self.z_dim = z_dim
        self.nc = nc
        self.encoder = nn.Sequential(
            nn.Conv2d(nc, 32, 4, 2, 1, bias=False),              # B,  128, 32, 32
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2, 1, bias=False),             # B,  256, 16, 16
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),             # B,  512,  8,  8
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),            # B, 1024,  4,  4
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            View((-1, 256*2*2)),                                 # B, 1024*2*2
            nn.Linear(256*2*2, z_dim)                            # B, z_dim
        )

        
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256*4*4),                           # B, 1024*4*4
            View((-1, 256, 4, 4)),                               # B, 1024,  4,  4
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),   # B,  512, 8, 8
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),    # B,  256, 16, 16
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 32, 4, 2, 1, bias=False),    # B,  128, 32, 32
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, nc, 1),                       # B,   nc, 32, 32
            nn.Tanh()
        )
        self.weight_init()

    def weight_init(self):
        for block in self._modules:
            try:
                for m in self._modules[block]:
                    kaiming_init(m)
            except:
                kaiming_init(block)

    def forward(self, x):
        z = self._encode(x)
        x_recon = self._decode(z)

        return x_recon, z

    def _encode(self, x):
        return self.encoder(x)

    def _decode(self, z):
        return self.decoder(z)
    
def kaiming_init(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        init.kaiming_normal_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0)
    elif isinstance(m, (nn.BatchNorm1d, nn.BatchNorm2d)):
        m.weight.data.fill_(1)
        if m.bias is not None:
            m.bias.data.fill_(0)

# %%
model = AE()
print(model)

data = torch.randn(10, 1, 32, 32)
with torch.no_grad():
    x_recon, z = model(data)
    
print(data.shape)
print(x_recon.shape, z.shape)
# Out:
# AE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): View()
#     (13): Linear(in_features=1024, out_features=32, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=32, out_features=4096, bias=True)
#     (1): View()
#     (2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#     (8): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): ConvTranspose2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#     (12): Tanh()
#   )
# )
# torch.Size([10, 1, 32, 32])
# torch.Size([10, 1, 32, 32]) torch.Size([10, 32])

# %% [markdown]
# ### Training

# %%
# loss function
criterion = nn.MSELoss()

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
n_epochs = 100

model.train()

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model.to(device)

for epoch in range(1, n_epochs+1):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for i, (images, _) in enumerate(train_loader):
        # _ stands in for labels,
        images = images.to(device)
        
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        model.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs, _ = model(images)
        # calculate the loss
        loss = criterion(outputs, images)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*images.size(0)
            
    # print avg training statistics 
    train_loss = train_loss/len(train_loader)
    print('Epoch: [{}/{}] \tTraining Loss: {:.6f}'.format(epoch, n_epochs, train_loss))
# Out:
# Epoch: [1/100] 	Training Loss: 3.972024
# Epoch: [2/100] 	Training Loss: 1.630230
# Epoch: [3/100] 	Training Loss: 1.343162
# Epoch: [4/100] 	Training Loss: 1.211358
# Epoch: [5/100] 	Training Loss: 1.112375
# Epoch: [6/100] 	Training Loss: 1.054039
# Epoch: [7/100] 	Training Loss: 1.008375
# Epoch: [8/100] 	Training Loss: 0.965131
# Epoch: [9/100] 	Training Loss: 0.924476
# Epoch: [10/100] 	Training Loss: 0.903346
# Epoch: [11/100] 	Training Loss: 0.873616
# Epoch: [12/100] 	Training Loss: 0.860441
# Epoch: [13/100] 	Training Loss: 0.832116
# Epoch: [14/100] 	Training Loss: 0.818137
# Epoch: [15/100] 	Training Loss: 0.799856
# Epoch: [16/100] 	Training Loss: 0.786949
# Epoch: [17/100] 	Training Loss: 0.774235
# Epoch: [18/100] 	Training Loss: 0.763034
# Epoch: [19/100] 	Training Loss: 0.759408
# Epoch: [20/100] 	Training Loss: 0.748886
# Epoch: [21/100] 	Training Loss: 0.745219
# Epoch: [22/100] 	Training Loss: 0.730524
# Epoch: [23/100] 	Training Loss: 0.722140
# Epoch: [24/100] 	Training Loss: 0.715601
# Epoch: [25/100] 	Training Loss: 0.712331
# Epoch: [26/100] 	Training Loss: 0.701665
# Epoch: [27/100] 	Training Loss: 0.700870
# Epoch: [28/100] 	Training Loss: 0.694104
# Epoch: [29/100] 	Training Loss: 0.687216
# Epoch: [30/100] 	Training Loss: 0.682690
# Epoch: [31/100] 	Training Loss: 0.678946
# Epoch: [32/100] 	Training Loss: 0.675981
# Epoch: [33/100] 	Training Loss: 0.671096
# Epoch: [34/100] 	Training Loss: 0.667156
# Epoch: [35/100] 	Training Loss: 0.662894
# Epoch: [36/100] 	Training Loss: 0.660824
# Epoch: [37/100] 	Training Loss: 0.654613
# Epoch: [38/100] 	Training Loss: 0.651212
# Epoch: [39/100] 	Training Loss: 0.649245
# Epoch: [40/100] 	Training Loss: 0.645895
# Epoch: [41/100] 	Training Loss: 0.643119
# Epoch: [42/100] 	Training Loss: 0.640841
# Epoch: [43/100] 	Training Loss: 0.639414
# Epoch: [44/100] 	Training Loss: 0.633566
# Epoch: [45/100] 	Training Loss: 0.635159
# Epoch: [46/100] 	Training Loss: 0.627705
# Epoch: [47/100] 	Training Loss: 0.626239
# Epoch: [48/100] 	Training Loss: 0.622989
# Epoch: [49/100] 	Training Loss: 0.621685
# Epoch: [50/100] 	Training Loss: 0.622517
# Epoch: [51/100] 	Training Loss: 0.623590
# Epoch: [52/100] 	Training Loss: 0.619424
# Epoch: [53/100] 	Training Loss: 0.615414
# Epoch: [54/100] 	Training Loss: 0.610249
# Epoch: [55/100] 	Training Loss: 0.613088
# Epoch: [56/100] 	Training Loss: 0.610701
# Epoch: [57/100] 	Training Loss: 0.608077
# Epoch: [58/100] 	Training Loss: 0.605706
# Epoch: [59/100] 	Training Loss: 0.601585
# Epoch: [60/100] 	Training Loss: 0.603649
# Epoch: [61/100] 	Training Loss: 0.600073
# Epoch: [62/100] 	Training Loss: 0.598669
# Epoch: [63/100] 	Training Loss: 0.598416
# Epoch: [64/100] 	Training Loss: 0.597688
# Epoch: [65/100] 	Training Loss: 0.597340
# Epoch: [66/100] 	Training Loss: 0.593378
# Epoch: [67/100] 	Training Loss: 0.595607
# Epoch: [68/100] 	Training Loss: 0.595038
# Epoch: [69/100] 	Training Loss: 0.590129
# Epoch: [70/100] 	Training Loss: 0.590892
# Epoch: [71/100] 	Training Loss: 0.587078
# Epoch: [72/100] 	Training Loss: 0.586772
# Epoch: [73/100] 	Training Loss: 0.586088
# Epoch: [74/100] 	Training Loss: 0.586508
# Epoch: [75/100] 	Training Loss: 0.583914
# Epoch: [76/100] 	Training Loss: 0.583896
# Epoch: [77/100] 	Training Loss: 0.579942
# Epoch: [78/100] 	Training Loss: 0.578622
# Epoch: [79/100] 	Training Loss: 0.580529
# Epoch: [80/100] 	Training Loss: 0.579448
# Epoch: [81/100] 	Training Loss: 0.576080
# Epoch: [82/100] 	Training Loss: 0.577290
# Epoch: [83/100] 	Training Loss: 0.576698
# Epoch: [84/100] 	Training Loss: 0.578136
# Epoch: [85/100] 	Training Loss: 0.574871
# Epoch: [86/100] 	Training Loss: 0.570308
# Epoch: [87/100] 	Training Loss: 0.574780
# Epoch: [88/100] 	Training Loss: 0.568105
# Epoch: [89/100] 	Training Loss: 0.570457
# Epoch: [90/100] 	Training Loss: 0.569101
# Epoch: [91/100] 	Training Loss: 0.567704
# Epoch: [92/100] 	Training Loss: 0.568692
# Epoch: [93/100] 	Training Loss: 0.567818
# Epoch: [94/100] 	Training Loss: 0.565044
# Epoch: [95/100] 	Training Loss: 0.562522
# Epoch: [96/100] 	Training Loss: 0.565742
# Epoch: [97/100] 	Training Loss: 0.563018
# Epoch: [98/100] 	Training Loss: 0.560199
# Epoch: [99/100] 	Training Loss: 0.564793
# Epoch: [100/100] 	Training Loss: 0.560836

# %% [markdown]
# ### Checking the results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = next(dataiter)
images = images.to(device)

# get sample outputs
output, _ = model(images)
# prep images for display
images = images.detach().cpu().numpy()


# use detach when it's an output that requires_grad
output = output.detach().cpu().numpy()

images = images[:20]
output = output[:20]

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for images, row in zip([images, output], axes):
    for img, ax in zip(images, row):
        ax.imshow(np.squeeze(img), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
